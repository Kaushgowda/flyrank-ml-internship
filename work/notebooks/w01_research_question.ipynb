# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Kaushgowda/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
### My LaneI selected **Lane 2: Refresh / Content Opportunity Scoring**.I chose this lane because it focuses on identifying which web pages should be reviewed first for refresh, improvement, or monitoring. This is an important business problem because organizations usually have many pages but limited time and resources. A data-driven approach can help prioritize the pages that are most likely to benefit from updates.I also selected this lane because it allows me to apply machine learning techniques while keeping the recommendations transparent and explainable

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
##Research Question: Which web pages should be reviewed first for refresh, improvement, or monitoring based on their performance data?

#Decision: Decide which pages should be prioritized for content refresh.

#Who takes the action? A content manager or SEO team.

#Action: Review the highest-ranked pages and decide whether to refresh, expand, rewrite, monitor, or keep them unchanged.

#Cost of a wrong recommendation: If a page is incorrectly prioritized, time and effort may be wasted on pages that do not need updates. If an important page is missed, the organization may lose opportunities to improve traffic and user engagement.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df = pd.read_csv(
    "content_refresh_anonymized.csv",
    engine="python",
    on_bad_lines="skip"
)
df.shape
# Out:
# (30000, 44)

# %%
df.shape
df.columns
# Out:
# Index(['content_id', 'client_id', 'search_volume', 'competition',
#        'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count',
#        'char_count', 'provider_used', 'model_used', 'impressions_90d',
#        'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d',
#        'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d',
#        'days_with_impressions', 'days_with_sessions', 'impressions_last_30d',
#        'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d',
#        'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier',
#        'age_tier_order', 'days_since_last_update', 'freshness_tier',
#        'word_count_tier', 'char_count_tier', 'ctr', 'avg_position',
#        'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier',
#        'position_tier', 'trend_direction', 'trend_pct'],
#       dtype='object')

# %%
# Basic information about the dataset

print("Number of rows and columns:", df.shape)

print("\nContent Types:")
print(df["content_type"].value_counts())

print("\nAverage CTR:")
print(df["ctr"].mean())

print("\nAverage Position:")
print(df["avg_position"].mean())
# Out:
# Number of rows and columns: (30000, 44)
#
# Content Types:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64
#
# Average CTR:
# 0.5107333333333334
#
# Average Position:
# 16.342380000000002

# %% [markdown]
# ### Quick Look at the Data
#
# The starter dataset contains **18,691 rows** and **44 columns**, providing a large amount of information for analysis. Most of the content consists of **keyword articles (16,935 pages)**, while smaller portions are Feedly articles (1,299) and comparison articles (456). The average **CTR (Click-Through Rate) is 0.535**, and the average search position is **16.27**. These statistics suggest that the dataset is large enough and contains meaningful performance metrics to support a content opportunity scoring project over the next seven weeks.

# %% [markdown]
# Section 4: Careful words
# ### Careful Words
#
# This project will provide data-driven recommendations about which pages should be reviewed for refresh or improvement. The results are intended to support decision-making based on patterns observed in the data. However, this project cannot prove that refreshing a page will definitely improve its performance or establish a cause-and-effect relationship. The recommendations should be treated as decision support rather than guaranteed outcomes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
